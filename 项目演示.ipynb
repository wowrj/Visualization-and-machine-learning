# %% [markdown]
# # 乌克兰危机下经济数据可视化以及投资决策
# ### by 朱仁杰

# %%
import dwsxfx
import qgfxmodel
import pyedraw
import matdraw
import screen_touzi

# %% [markdown]
# ## matplotlib 绘制大宗商品

# %%
matdraw.matdraw_dazong()
# Out:
# 保存在 out\大宗商品.jpg

# %% [markdown]
# ## matplotlib 绘制主要货币

# %%
matdraw.matdraw_huobi()
# Out:
# 保存在 out\主要货币.jpg

# %% [markdown]
# ## matplotlib 绘制国内股指

# %%
matdraw.matdraw_gp()
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# 今天是 2022-06-10
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
# 保存在 out\国内股指.jpg

# %% [markdown]
# ## matplotlib 绘制聚类指导行业投资

# %%
matdraw.matdraw_hychoose()
# Out:
# login success!
# read okistory_k_data_plus respond  error_msg:successlogout success!
# 值得投资 ['1000信息' '1000公用' '1000可选' '1000工业' '1000材料' '1000消费' '1000金融' '300 金融'
#  '300公用' '300可选' '300工业' '300材料' '300消费' '300金融' '380信息' '380公用' '380可选'
#  '380工业' '380材料' '380消费' '380电信' '上证信息' '上证公用' '上证可选' '上证工业' '上证材料' '上证消费'
#  '上证电信' '上证金融' '中证信息' '中证消费' '中证金融' '全指信息' '全指可选' '全指材料' '全指消费' '全指金融'
#  '国证交运' '国证传媒' '国证汽车' '国证电力' '国证证券' '国证通信' '国证钢铁' '国证银行' '基建工程' '深互联网'
#  '深证信息' '深证公用' '深证可选' '深证工业' '深证材料' '深证消费' '深证电信' '深证金融']
# 不值得投资 ['1000医药' '1000能源' '300 医药' '300医药' '300能源' '380医药' '380能源' '380金融' '上证医药'
#  '上证能源' '中证煤炭' '中证能源' '全指医药' '全指能源' '国证农牧' '国证油气' '国证煤炭' '深A医药' '深证医药'
#  '深证能源']
# 保存在 out\聚类指导行业选择.jpg

# %% [markdown]
# ## pyecharts 绘制乌克兰危机下投资大屏

# %%
pyedraw.pyedraw_sjdp()
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# 今天是 2022-06-10
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
# 保存至 out\危机相关经济数据1.0.html

# %% [markdown]
# ## pyecharts 绘制聚类指导行业投资

# %%
pyedraw.pyedraw_hychoose()
# Out:
# login success!
# read oklogout success!lus respond  error_msg:success
# 保存至 out\聚类指导行业投资.html

# %% [markdown]
# ## LSTM 训练情感分析模型

# %%
qgfxmodel.model_train('data\\qgfx\\train_Data.csv',100,25,25,'data\\qgfx\\qgfx.h5',5,32)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 25, 25)            48925
#
#  lstm (LSTM)                 (None, 100)               50400
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 2)                 202
#
# =================================================================
# Total params: 99,527
# Trainable params: 99,527
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 117/117 [==============================] - 11s 39ms/step - loss: 0.5813 - accuracy: 0.7057 - val_loss: 0.4114 - val_accuracy: 0.8101
# Epoch 2/5
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3758 - accuracy: 0.8395 - val_loss: 0.3942 - val_accuracy: 0.8125
# Epoch 3/5
# 117/117 [==============================] - 3s 25ms/step - loss: 0.3107 - accuracy: 0.8667 - val_loss: 0.3952 - val_accuracy: 0.8173
# Epoch 4/5
# 117/117 [==============================] - 2s 21ms/step - loss: 0.2708 - accuracy: 0.8924 - val_loss: 0.4387 - val_accuracy: 0.8221
# Epoch 5/5
# 117/117 [==============================] - 3s 21ms/step - loss: 0.2473 - accuracy: 0.8972 - val_loss: 0.4260 - val_accuracy: 0.8317
# start:0, end:1
# y_predict: [[0.00886836 0.9911316 ]]
# label_predict:2.0, label_true:2.0
# 这么大盘子，没有机构参与，再好 2.0 2.0
# start:1, end:2
# y_predict: [[0.97580296 0.02419702]]
# label_predict:1.0, label_true:1.0
# 资金搏弈红线向上 1.0 1.0
# start:2, end:3
# y_predict: [[0.20280534 0.7971946 ]]
# label_predict:2.0, label_true:2.0
# 跌停板 2.0 2.0
# start:3, end:4
# y_predict: [[0.03841906 0.96158093]]
# label_predict:2.0, label_true:2.0
# 你总是倒数第一 2.0 2.0
# start:4, end:5
# y_predict: [[0.40662166 0.59337837]]
# label_predict:2.0, label_true:1.0
# 周一全部增持完吧。 1.0 2.0
# start:5, end:6
# y_predict: [[0.06615788 0.9338422 ]]
# label_predict:2.0, label_true:2.0
# 我反对这门亲事[呲牙] 2.0 2.0
# start:6, end:7
# y_predict: [[0.98375434 0.01624569]]
# label_predict:1.0, label_true:1.0
# 从基本面和盘面来看，中远茅后市要大涨，大家珍惜！ 1.0 1.0
# start:7, end:8
# y_predict: [[0.9947672  0.00523281]]
# label_predict:1.0, label_true:1.0
# 冲冲冲冲冲上去 1.0 1.0
# start:8, end:9
# y_predict: [[0.92846996 0.07153002]]
# label_predict:1.0, label_true:1.0
# 这么多人唱多？明天冲高我就卖。 1.0 1.0
# start:9, end:10
# y_predict: [[0.8982512  0.10174879]]
# label_predict:1.0, label_true:1.0
# 海运指数涨了一个月 1.0 1.0
# start:10, end:11
# y_predict: [[0.11772009 0.88227993]]
# label_predict:2.0, label_true:2.0
# 被我买崩了吗 2.0 2.0
# start:11, end:12
# y_predict: [[8.4375672e-04 9.9915624e-01]]
# label_predict:2.0, label_true:2.0
# 真废物真搞笑，全是炒作 2.0 2.0
# start:12, end:13
# y_predict: [[0.8814073  0.11859274]]
# label_predict:1.0, label_true:1.0
# 回来干，看好 1.0 1.0
# start:13, end:14
# y_predict: [[0.00234872 0.9976513 ]]
# label_predict:2.0, label_true:2.0
# 2022最大笑话，中远海控的董秘郭 2.0 2.0
# start:14, end:15
# y_predict: [[7.6161174e-04 9.9923837e-01]]
# label_predict:2.0, label_true:1.0
# 一片欢声笑语 1.0 2.0
# start:15, end:16
# y_predict: [[1.7008536e-04 9.9982989e-01]]
# label_predict:2.0, label_true:2.0
# 中远海控每天都是压盘和托盘，想上涨比登天还难! 2.0 2.0
# start:16, end:17
# y_predict: [[0.0012795 0.9987205]]
# label_predict:2.0, label_true:2.0
# 板块都比这垃圾涨得多！ 2.0 2.0
# start:17, end:18
# y_predict: [[0.8545827  0.14541721]]
# label_predict:1.0, label_true:1.0
# 赞成 1.0 1.0
# start:18, end:19
# y_predict: [[0.8602697 0.1397303]]
# label_predict:1.0, label_true:1.0
# 从软件看都是大单在吸筹为啥呀，有消息吗？ 1.0 1.0
# start:19, end:20
# y_predict: [[4.3544604e-04 9.9956459e-01]]
# label_predict:2.0, label_true:2.0
# 万绿龟，名副其实[滴汗][滴汗] 2.0 2.0
# start:20, end:21
# y_predict: [[0.03255974 0.9674403 ]]
# label_predict:2.0, label_true:2.0
# 大洗盘，无底洞 2.0 2.0
# start:21, end:22
# y_predict: [[0.92947185 0.07052814]]
# label_predict:1.0, label_true:1.0
# 601919，北向资金今日净买入第一名 1.0 1.0
# start:22, end:23
# y_predict: [[0.05051925 0.9494807 ]]
# label_predict:2.0, label_true:1.0
# 15.34的那一手，很有水平吖 1.0 2.0
# start:23, end:24
# y_predict: [[3.3471611e-04 9.9966526e-01]]
# label_predict:2.0, label_true:2.0
# 真的是垃圾股，涨一次没轮到，跌 2.0 2.0
# start:24, end:25
# y_predict: [[0.30634645 0.6936535 ]]
# label_predict:2.0, label_true:2.0
# 这企业都是都是汉间 2.0 2.0
# start:25, end:26
# y_predict: [[0.00405448 0.9959455 ]]
# label_predict:2.0, label_true:2.0
# 000多亿市值 开盘都上下跳动，这个猪力太几把菜了 2.0 2.0
# start:26, end:27
# y_predict: [[5.8055465e-04 9.9941945e-01]]
# label_predict:2.0, label_true:2.0
# 卖了卖了，董秘不说人话，豺狼啊 2.0 2.0
# start:27, end:28
# y_predict: [[0.891568   0.10843208]]
# label_predict:1.0, label_true:1.0
# 可以涨停了吗 1.0 1.0
# start:28, end:29
# y_predict: [[0.07197745 0.9280225 ]]
# label_predict:2.0, label_true:2.0
# 北向开砸了xdm，好自为之吧 2.0 2.0
# start:29, end:30
# y_predict: [[0.00337164 0.99662834]]
# label_predict:2.0, label_true:2.0
# 今天怎么这么反常，按海狗套路， 2.0 2.0
# start:30, end:31
# y_predict: [[0.06817771 0.9318223 ]]
# label_predict:2.0, label_true:2.0
# 股价拉到60，不用你分红了，谢谢合作 2.0 2.0
# start:31, end:32
# y_predict: [[0.9935056  0.00649433]]
# label_predict:1.0, label_true:1.0
# 中远海控：上海口岸的货量已较前几周有较明显的恢复 1.0 1.0
# start:32, end:33
# y_predict: [[0.6723815  0.32761845]]
# label_predict:1.0, label_true:1.0
# 从现在开始，公司狂拉三个板，到 1.0 1.0
# start:33, end:34
# y_predict: [[0.03800408 0.9619959 ]]
# label_predict:2.0, label_true:1.0
# 大盘都红了  你有什么理由下跌 1.0 2.0
# start:34, end:35
# y_predict: [[0.948037   0.05196299]]
# label_predict:1.0, label_true:2.0
# 红0.87元排在沪深股市中是190名中但，股价排在 2.0 1.0
# start:35, end:36
# y_predict: [[0.1586934  0.84130657]]
# label_predict:2.0, label_true:2.0
# 这么多唱黑文章，这是存心要打压股价啊 2.0 2.0
# start:36, end:37
# y_predict: [[0.01171758 0.9882824 ]]
# label_predict:2.0, label_true:2.0
# 趋势真难看…下跌概率明显大于上涨…估计还是要下探一 2.0 2.0
# start:37, end:38
# y_predict: [[0.63830316 0.36169684]]
# label_predict:1.0, label_true:1.0
# 中远茅必大涨，不接受反驳！ 1.0 1.0
# start:38, end:39
# y_predict: [[0.89375013 0.10624989]]
# label_predict:1.0, label_true:1.0
# 5-10天利润增持 1.0 1.0
# start:39, end:40
# y_predict: [[0.00383514 0.9961649 ]]
# label_predict:2.0, label_true:2.0
# 一群韭菜花越抱怨越不会涨的 2.0 2.0
# start:40, end:41
# y_predict: [[0.17408094 0.82591903]]
# label_predict:2.0, label_true:2.0
# 人家五千万就拉涨停。你五千万才涨一个多点。[捂脸] 2.0 2.0
# start:41, end:42
# y_predict: [[0.13921231 0.86078775]]
# label_predict:2.0, label_true:2.0
# 先卖为敬，再也不见 2.0 2.0
# start:42, end:43
# y_predict: [[9.096811e-04 9.990903e-01]]
# label_predict:2.0, label_true:2.0
# 机构对管理层的愤怒，连续几天砸盘 2.0 2.0
# start:43, end:44
# y_predict: [[0.01108321 0.98891675]]
# label_predict:2.0, label_true:2.0
# 板块倒数第一了 2.0 2.0
# start:44, end:45
# y_predict: [[0.05202535 0.9479747 ]]
# label_predict:2.0, label_true:2.0
# 乐色 2.0 2.0
# start:45, end:46
# y_predict: [[1.8421686e-04 9.9981576e-01]]
# label_predict:2.0, label_true:2.0
# 利润比所有航运公司最低，垃圾 2.0 2.0
# start:46, end:47
# y_predict: [[0.71681356 0.28318647]]
# label_predict:1.0, label_true:2.0
# 卖飞南油，买入轮船，被套 2.0 1.0
# start:47, end:48
# y_predict: [[0.04091143 0.9590886 ]]
# label_predict:2.0, label_true:2.0
# 对海控的信心彻底垮了 2.0 2.0
# start:48, end:49
# y_predict: [[0.00270877 0.99729115]]
# label_predict:2.0, label_true:2.0
# 放心，百分百大绿下午 2.0 2.0
# start:49, end:50
# y_predict: [[0.0468241  0.95317596]]
# label_predict:2.0, label_true:2.0
# 分红一般股价会下跌，拿股民的钱 2.0 2.0
# start:50, end:51
# y_predict: [[0.0058008  0.99419916]]
# label_predict:2.0, label_true:2.0
# 2.5.31】这盘面真没啥说的，就是个震荡走势，到 2.0 2.0
# start:51, end:52
# y_predict: [[0.9718472  0.02815284]]
# label_predict:1.0, label_true:1.0
# 敢不敢涨停一下 1.0 1.0
# start:52, end:53
# y_predict: [[0.24803875 0.7519613 ]]
# label_predict:2.0, label_true:2.0
# 明天丢了看别的 2.0 2.0
# start:53, end:54
# y_predict: [[0.00959094 0.990409  ]]
# label_predict:2.0, label_true:2.0
# 散户，你们看不见吗？大盘拉升，海控都不跟了，这么明 2.0 2.0
# start:54, end:55
# y_predict: [[0.00386342 0.9961366 ]]
# label_predict:2.0, label_true:2.0
# 洗盘还是新的下跌开始了？周三，股市观瞻 2.0 2.0
# start:55, end:56
# y_predict: [[0.17865734 0.82134265]]
# label_predict:2.0, label_true:1.0
# 强烈建议公司回购股票 1.0 2.0
# start:56, end:57
# y_predict: [[0.19725282 0.80274713]]
# label_predict:2.0, label_true:2.0
# 整个板块上涨，这个股不涨，啥意思？有没有能说明白的 2.0 2.0
# start:57, end:58
# y_predict: [[0.00815011 0.9918499 ]]
# label_predict:2.0, label_true:2.0
# 航运订单暴降！利润腰斩，死守没有！ 2.0 2.0
# start:58, end:59
# y_predict: [[0.659173 0.340827]]
# label_predict:1.0, label_true:1.0
# 继续买买到涨为止就对了 1.0 1.0
# start:59, end:60
# y_predict: [[0.03533255 0.96466744]]
# label_predict:2.0, label_true:2.0
# 遇担保赶紧跑，撤！12左右再进！ 2.0 2.0
# start:60, end:61
# y_predict: [[0.994635   0.00536503]]
# label_predict:1.0, label_true:1.0
# 第一目标价20 1.0 1.0
# start:61, end:62
# y_predict: [[0.8945672  0.10543282]]
# label_predict:1.0, label_true:2.0
# 业绩很好，但趋势向下，只能看不 2.0 1.0
# start:62, end:63
# y_predict: [[0.4652638  0.53473616]]
# label_predict:2.0, label_true:1.0
# 一个胜利的大会,团结的大会,成功的大会 1.0 2.0
# start:63, end:64
# y_predict: [[0.39022973 0.60977024]]
# label_predict:2.0, label_true:2.0
# 高点越来越低， 2.0 2.0
# start:64, end:65
# y_predict: [[0.00110193 0.998898  ]]
# label_predict:2.0, label_true:2.0
# 再见海狗，等董秘学会好好说话， 2.0 2.0
# start:65, end:66
# y_predict: [[2.1558444e-04 9.9978441e-01]]
# label_predict:2.0, label_true:2.0
# 恶心他m给恶心开门，恶心到家了 2.0 2.0
# start:66, end:67
# y_predict: [[0.8189186  0.18108141]]
# label_predict:1.0, label_true:1.0
# 海特(600428):业绩超预期涨停！！明天连板！ 1.0 1.0
# start:67, end:68
# y_predict: [[0.12069579 0.87930423]]
# label_predict:2.0, label_true:2.0
# 我靠~我还以为卖飞了，结果又下来了 2.0 2.0
# start:68, end:69
# y_predict: [[0.37561622 0.62438375]]
# label_predict:2.0, label_true:1.0
# 今天清仓的朋友赚了，明天开始开启大幅杀跌。。。 1.0 2.0
# start:69, end:70
# y_predict: [[0.95083493 0.04916513]]
# label_predict:1.0, label_true:1.0
# 919中远回购方式是最适合国家、公司、股东权利的！ 1.0 1.0
# start:70, end:71
# y_predict: [[0.09672149 0.90327847]]
# label_predict:2.0, label_true:2.0
# 这么多人都看空，就放心了。 2.0 2.0
# start:71, end:72
# y_predict: [[0.09073817 0.9092619 ]]
# label_predict:2.0, label_true:2.0
# 中远海控的管理层，令人汗颜！呼 2.0 2.0
# start:72, end:73
# y_predict: [[3.2401487e-04 9.9967599e-01]]
# label_predict:2.0, label_true:2.0
# 垃圾股，板块涨你不涨，板块跌你 2.0 2.0
# start:73, end:74
# y_predict: [[0.9763932  0.02360679]]
# label_predict:1.0, label_true:1.0
# 涨停，拿住筹码 1.0 1.0
# start:74, end:75
# y_predict: [[0.15821093 0.84178907]]
# label_predict:2.0, label_true:2.0
# 海控这条蠢猪，太浪费我的资金、 2.0 2.0
# start:75, end:76
# y_predict: [[0.04077949 0.9592205 ]]
# label_predict:2.0, label_true:2.0
# 中远海控就这样堕落下去。 2.0 2.0
# start:76, end:77
# y_predict: [[0.00123251 0.9987675 ]]
# label_predict:2.0, label_true:2.0
# 股价全天压在水下，吧内群情汹涌，管理层不为所动，区 2.0 2.0
# start:77, end:78
# y_predict: [[0.06192098 0.938079  ]]
# label_predict:2.0, label_true:2.0
# 倒数第一啊，靠 2.0 2.0
# start:78, end:79
# y_predict: [[0.02592675 0.9740733 ]]
# label_predict:2.0, label_true:2.0
# 还不如ST 2.0 2.0
# start:79, end:80
# y_predict: [[9.9966919e-01 3.3083488e-04]]
# label_predict:1.0, label_true:1.0
# 加油加油再加油 1.0 1.0
# start:80, end:81
# y_predict: [[0.00566611 0.99433386]]
# label_predict:2.0, label_true:2.0
# 5.21进去 都跌到了15.15 做个t就这么难吗 2.0 2.0
# start:81, end:82
# y_predict: [[0.01751816 0.98248184]]
# label_predict:2.0, label_true:2.0
# 海狗什么时候分红就提前跑，不然 2.0 2.0
# start:82, end:83
# y_predict: [[0.14023682 0.8597632 ]]
# label_predict:2.0, label_true:2.0
# 下跌通道的股别买 2.0 2.0
# start:83, end:84
# y_predict: [[0.90491986 0.09508011]]
# label_predict:1.0, label_true:1.0
# 周线金叉时候做中长线耐心持有一个二十厘米跑不了 1.0 1.0
# start:84, end:85
# y_predict: [[0.01082512 0.98917496]]
# label_predict:2.0, label_true:2.0
# 中远海控的怪现象：大盘跌，跟着跌；大盘涨，不跟涨。 2.0 2.0
# start:85, end:86
# y_predict: [[0.01376095 0.986239  ]]
# label_predict:2.0, label_true:2.0
# 究竟要跌到什么时候 2.0 2.0
# start:86, end:87
# y_predict: [[3.2009865e-04 9.9967992e-01]]
# label_predict:2.0, label_true:2.0
# 天天在股吧骂，有啥用，割肉又没那个决心…结果越套越 2.0 2.0
# start:87, end:88
# y_predict: [[0.94396234 0.05603774]]
# label_predict:1.0, label_true:1.0
# 该起飞了兄弟 1.0 1.0
# start:88, end:89
# y_predict: [[0.09726195 0.902738  ]]
# label_predict:2.0, label_true:2.0
# 一季报业绩都没拉过这么黑的好得 2.0 2.0
# start:89, end:90
# y_predict: [[0.02929207 0.9707079 ]]
# label_predict:2.0, label_true:2.0
# 真的还会有人被诱高进来么 2.0 2.0
# start:90, end:91
# y_predict: [[0.9989053  0.00109469]]
# label_predict:1.0, label_true:1.0
# 买入][买入][买入][买入][买入][买入][买 1.0 1.0
# start:91, end:92
# y_predict: [[0.993889   0.00611105]]
# label_predict:1.0, label_true:1.0
# 是金子总会发光！ 1.0 1.0
# start:92, end:93
# y_predict: [[0.3448021 0.6551979]]
# label_predict:2.0, label_true:2.0
# 负面情绪越来越严重，盘面看起来 2.0 2.0
# start:93, end:94
# y_predict: [[0.00510944 0.9948906 ]]
# label_predict:2.0, label_true:2.0
# 投票就是暴露了散户太多这个事实 2.0 2.0
# start:94, end:95
# y_predict: [[0.00282254 0.9971775 ]]
# label_predict:2.0, label_true:1.0
# 韭菜们已经不错了，没有大跌，继 1.0 2.0
# start:95, end:96
# y_predict: [[7.714733e-04 9.992285e-01]]
# label_predict:2.0, label_true:2.0
# 我天天盯盘就是来见证你是如何跌跌不休，你就是这样回 2.0 2.0
# start:96, end:97
# y_predict: [[0.71048135 0.28951862]]
# label_predict:1.0, label_true:2.0
# 不能有执念 2.0 1.0
# start:97, end:98
# y_predict: [[0.5100602 0.4899398]]
# label_predict:1.0, label_true:1.0
# 周评：放弃传统持股待涨，选择低吸高抛，落袋为安，到 1.0 1.0
# start:98, end:99
# y_predict: [[0.00785283 0.99214715]]
# label_predict:2.0, label_true:2.0
# 就怕这货分红了，股价继续跌[怒] 2.0 2.0
# start:99, end:100
# y_predict: [[0.3596045 0.6403955]]
# label_predict:2.0, label_true:1.0
# 大盘二次探底来了 1.0 2.0
# start:100, end:101
# y_predict: [[0.12164526 0.8783548 ]]
# label_predict:2.0, label_true:2.0
# 涨不动啊，有气无力的[滴汗] 2.0 2.0
# start:101, end:102
# y_predict: [[1.4945427e-04 9.9985051e-01]]
# label_predict:2.0, label_true:2.0
# 垃圾 2.0 2.0
# start:102, end:103
# y_predict: [[0.756386   0.24361403]]
# label_predict:1.0, label_true:1.0
# 不上30天理难容 1.0 1.0
# start:103, end:104
# y_predict: [[0.32973582 0.6702642 ]]
# label_predict:2.0, label_true:2.0
# 加油，倒数第一的位置是你的。 2.0 2.0
# start:104, end:105
# y_predict: [[0.01798131 0.9820187 ]]
# label_predict:2.0, label_true:2.0
# 走了走了，拿不住了，烦了， 2.0 2.0
# start:105, end:106
# y_predict: [[0.970682   0.02931794]]
# label_predict:1.0, label_true:1.0
# 冲冲冲↗ 1.0 1.0
# start:106, end:107
# y_predict: [[0.00509904 0.99490094]]
# label_predict:2.0, label_true:2.0
# 到底万敏盖土了没有？ 2.0 2.0
# start:107, end:108
# y_predict: [[0.98854977 0.01145024]]
# label_predict:1.0, label_true:1.0
# 收盘时来一波涨停 1.0 1.0
# start:108, end:109
# y_predict: [[0.00793421 0.99206585]]
# label_predict:2.0, label_true:1.0
# boll线收紧应该不会再往下走了估 1.0 2.0
# start:109, end:110
# y_predict: [[0.00724693 0.99275315]]
# label_predict:2.0, label_true:2.0
# 鳖孙股票 2.0 2.0
# start:110, end:111
# y_predict: [[0.00272336 0.9972766 ]]
# label_predict:2.0, label_true:2.0
# 笑死我了，我是打死没想到，海控能录 2.0 2.0
# start:111, end:112
# y_predict: [[0.02688238 0.97311765]]
# label_predict:2.0, label_true:2.0
# 海控，你伤害了股民的心，亏损的 2.0 2.0
# start:112, end:113
# y_predict: [[0.6260558 0.3739442]]
# label_predict:1.0, label_true:2.0
# 每天射一秒之后就全天了 2.0 1.0
# start:113, end:114
# y_predict: [[0.95885235 0.04114771]]
# label_predict:1.0, label_true:1.0
# 我是一个急性子快点往上冲才是正道[主力][主力] 1.0 1.0
# start:114, end:115
# y_predict: [[0.07408954 0.9259105 ]]
# label_predict:2.0, label_true:2.0
# 收盘绿油油 2.0 2.0
# start:115, end:116
# y_predict: [[0.8978748  0.10212521]]
# label_predict:1.0, label_true:1.0
# 【一万块实盘炒股】中远海控今天买3手，明天再加剩下 1.0 1.0
# start:116, end:117
# y_predict: [[1.4667639e-04 9.9985325e-01]]
# label_predict:2.0, label_true:2.0
# 大垃圾 2.0 2.0
# start:117, end:118
# y_predict: [[0.02545843 0.97454154]]
# label_predict:2.0, label_true:2.0
# 分红后马上除息，其实一分钱没有分到，孙子们说这样公 2.0 2.0
# start:118, end:119
# y_predict: [[0.00297197 0.99702805]]
# label_predict:2.0, label_true:2.0
# 为什么不动1、没庄、资金天天在流出2、没人玩他，看 2.0 2.0
# start:119, end:120
# y_predict: [[0.9868558  0.01314417]]
# label_predict:1.0, label_true:1.0
# 买了点试试水，下个礼拜不及预期 1.0 1.0
# start:120, end:121
# y_predict: [[0.9795899  0.02041017]]
# label_predict:1.0, label_true:1.0
# 瞅瞅这两天的消息，嘿嘿，怕是有人煽风点火，大家猜是 1.0 1.0
# start:121, end:122
# y_predict: [[0.23351046 0.76648957]]
# label_predict:2.0, label_true:2.0
# 紧跟大盘 2.0 2.0
# start:122, end:123
# y_predict: [[0.8668087  0.13319133]]
# label_predict:1.0, label_true:1.0
# 大庄可以的，逆天而行哈哈哈哈 1.0 1.0
# start:123, end:124
# y_predict: [[0.08240373 0.9175962 ]]
# label_predict:2.0, label_true:2.0
# 太拉级 2.0 2.0
# start:124, end:125
# y_predict: [[0.14778334 0.85221666]]
# label_predict:2.0, label_true:2.0
# 一直在我的成本线徘徊，等我卖了估计就涨了 2.0 2.0
# start:125, end:126
# y_predict: [[0.00643833 0.9935616 ]]
# label_predict:2.0, label_true:2.0
# 最佳董秘投票啦！每人每天可以投 2.0 2.0
# start:126, end:127
# y_predict: [[0.7499476  0.25005233]]
# label_predict:1.0, label_true:1.0
# 让子弹飞吧 1.0 1.0
# start:127, end:128
# y_predict: [[0.68544424 0.31455573]]
# label_predict:1.0, label_true:2.0
# 今年起绝对下坡的起点！ 2.0 1.0
# start:128, end:129
# y_predict: [[0.9523311 0.0476688]]
# label_predict:1.0, label_true:1.0
# 冲啊，排第一 1.0 1.0
# start:129, end:130
# y_predict: [[0.00658785 0.9934122 ]]
# label_predict:2.0, label_true:2.0
# 得了软骨病，没救了。 2.0 2.0
# start:130, end:131
# y_predict: [[4.527509e-04 9.995472e-01]]
# label_predict:2.0, label_true:2.0
# 分红有屁用，只对大股东有用，散户和服民就是分自己的 2.0 2.0
# start:131, end:132
# y_predict: [[0.43313012 0.56686985]]
# label_predict:2.0, label_true:2.0
# 让你给我添堵 2.0 2.0
# start:132, end:133
# y_predict: [[0.36997277 0.6300272 ]]
# label_predict:2.0, label_true:2.0
# 散户买，外资卖，股价会好吗 2.0 2.0
# start:133, end:134
# y_predict: [[0.9320659 0.0679341]]
# label_predict:1.0, label_true:1.0
# 一季度净利润276.17亿元 同比增长78.73% 1.0 1.0
# start:134, end:135
# y_predict: [[0.00982509 0.9901749 ]]
# label_predict:2.0, label_true:2.0
# 你看看，好多人都对你失去信心了 2.0 2.0
# start:135, end:136
# y_predict: [[0.9554137  0.04458624]]
# label_predict:1.0, label_true:2.0
# 请理智看待，股市有风险，别一味地听人家吹 2.0 1.0
# start:136, end:137
# y_predict: [[0.63090074 0.36909917]]
# label_predict:1.0, label_true:1.0
# 拉了 1.0 1.0
# start:137, end:138
# y_predict: [[0.9065485  0.09345149]]
# label_predict:1.0, label_true:1.0
# 抄底了抄底了 1.0 1.0
# start:138, end:139
# y_predict: [[0.11285317 0.8871469 ]]
# label_predict:2.0, label_true:2.0
# 死等吧 2.0 2.0
# start:139, end:140
# y_predict: [[0.00437687 0.9956232 ]]
# label_predict:2.0, label_true:2.0
# xdm直接砸跌停吧啥都别说了 2.0 2.0
# start:140, end:141
# y_predict: [[0.00754548 0.9924545 ]]
# label_predict:2.0, label_true:2.0
# 恶庄控盘 2.0 2.0
# start:141, end:142
# y_predict: [[3.8640723e-05 9.9996138e-01]]
# label_predict:2.0, label_true:2.0
# 这个倒霉催的海狗，谁买谁倒霉， 2.0 2.0
# start:142, end:143
# y_predict: [[0.958727   0.04127299]]
# label_predict:1.0, label_true:1.0
# 明天涨停！ 1.0 1.0
# start:143, end:144
# y_predict: [[0.99820566 0.00179434]]
# label_predict:1.0, label_true:1.0
# 火箭发射 1.0 1.0
# start:144, end:145
# y_predict: [[0.0095008 0.9904992]]
# label_predict:2.0, label_true:2.0
# 有鲜有嫩的新韭菜[捂脸][捂脸][ 2.0 2.0
# start:145, end:146
# y_predict: [[3.4431677e-04 9.9965572e-01]]
# label_predict:2.0, label_true:2.0
# 海控周线图，绿圈位置macd还没金叉。还没达到我心 2.0 2.0
# start:146, end:147
# y_predict: [[0.13430662 0.8656934 ]]
# label_predict:2.0, label_true:1.0
# 港股海控突破压力线，感觉明天国内海控要大涨！ 1.0 2.0
# start:147, end:148
# y_predict: [[0.6811496  0.31885043]]
# label_predict:1.0, label_true:2.0
# 今年的高点是15？ 2.0 1.0
# start:148, end:149
# y_predict: [[0.942513   0.05748697]]
# label_predict:1.0, label_true:1.0
# 海发要起飞了 1.0 1.0
# start:149, end:150
# y_predict: [[0.07355161 0.92644835]]
# label_predict:2.0, label_true:2.0
# 盛航都板了，你不动一动吗？？？ 2.0 2.0
# start:150, end:151
# y_predict: [[0.02201227 0.97798777]]
# label_predict:2.0, label_true:2.0
# 了三次，也没更多韭菜进来了，14.5像一座大山一般 2.0 2.0
# start:151, end:152
# y_predict: [[0.01427165 0.9857283 ]]
# label_predict:2.0, label_true:2.0
# 这货清仓了，亏了1万 2.0 2.0
# start:152, end:153
# y_predict: [[0.37221038 0.6277896 ]]
# label_predict:2.0, label_true:1.0
# 好久都没有听到要坚守时间的玫瑰，这句超经典的话了， 1.0 2.0
# start:153, end:154
# y_predict: [[0.00609825 0.9939017 ]]
# label_predict:2.0, label_true:2.0
# 万敏啊你真不是个人啊 2.0 2.0
# start:154, end:155
# y_predict: [[0.0067096 0.9932904]]
# label_predict:2.0, label_true:2.0
# 去年入股市买了这破股快一年了人都要整疯了。 2.0 2.0
# start:155, end:156
# y_predict: [[0.07149634 0.92850363]]
# label_predict:2.0, label_true:1.0
# 控：控股股东拟累计15亿元-30亿元增持公司A股和 1.0 2.0
# start:156, end:157
# y_predict: [[0.11554942 0.8844506 ]]
# label_predict:2.0, label_true:2.0
# 全部反对，回购也反对，一起毁灭 2.0 2.0
# start:157, end:158
# y_predict: [[0.00182123 0.99817884]]
# label_predict:2.0, label_true:2.0
# 这控盘太恶心了 2.0 2.0
# start:158, end:159
# y_predict: [[0.30550477 0.69449526]]
# label_predict:2.0, label_true:2.0
# 老铁们联合起来要求公司“回购股票并注销“，这才是关 2.0 2.0
# start:159, end:160
# y_predict: [[6.8701355e-04 9.9931300e-01]]
# label_predict:2.0, label_true:2.0
# 万绿帽及高管没责任，没格局，没嵴梁，没诚信，敷衍股 2.0 2.0
# start:160, end:161
# y_predict: [[0.21503003 0.7849699 ]]
# label_predict:2.0, label_true:2.0
# 今天就这样的没有量不会有太大波 2.0 2.0
# start:161, end:162
# y_predict: [[0.07775293 0.92224705]]
# label_predict:2.0, label_true:1.0
# .05.12】上海港4月集装箱吞吐量已恢复到去年八 1.0 2.0
# start:162, end:163
# y_predict: [[0.03987624 0.9601238 ]]
# label_predict:2.0, label_true:2.0
# 下跌趋势改变不了的 2.0 2.0
# start:163, end:164
# y_predict: [[0.03801793 0.9619821 ]]
# label_predict:2.0, label_true:2.0
# 海狗的走势 2.0 2.0
# start:164, end:165
# y_predict: [[0.06665897 0.933341  ]]
# label_predict:2.0, label_true:2.0
# 我14.2本，今天清仓了太难受了 2.0 2.0
# start:165, end:166
# y_predict: [[0.8455543  0.15444568]]
# label_predict:1.0, label_true:1.0
# [偷笑] 1.0 1.0
# start:166, end:167
# y_predict: [[0.15811278 0.84188724]]
# label_predict:2.0, label_true:1.0
# 卖了房子，钱没地方去，14满仓了，股息也有百分6点 1.0 2.0
# start:167, end:168
# y_predict: [[0.0018881  0.99811196]]
# label_predict:2.0, label_true:2.0
# 绿万早点回家吧，不要出来祸害人呢 2.0 2.0
# start:168, end:169
# y_predict: [[0.00777548 0.99222445]]
# label_predict:2.0, label_true:2.0
# 汽车股都疯了，你还在这磨磨唧唧的， 2.0 2.0
# start:169, end:170
# y_predict: [[0.583436   0.41656402]]
# label_predict:1.0, label_true:2.0
# 集中营里的这届散户喜欢追高，而且怨气很重。没加杠杆 2.0 1.0
# start:170, end:171
# y_predict: [[0.9326881  0.06731185]]
# label_predict:1.0, label_true:2.0
# 今天放量负7 2.0 1.0
# start:171, end:172
# y_predict: [[0.05204266 0.94795734]]
# label_predict:2.0, label_true:2.0
# 业绩好在中国有毛用，照样跌 2.0 2.0
# start:172, end:173
# y_predict: [[2.5440319e-04 9.9974555e-01]]
# label_predict:2.0, label_true:2.0
# 下半年估计半年赚不到现在一个月的钱，周期股就是垃圾 2.0 2.0
# start:173, end:174
# y_predict: [[2.303481e-04 9.997696e-01]]
# label_predict:2.0, label_true:2.0
# 这股庄也是无能，不会涨的垃圾股。 2.0 2.0
# start:174, end:175
# y_predict: [[0.03350553 0.9664945 ]]
# label_predict:2.0, label_true:2.0
# 你个苟远 2.0 2.0
# start:175, end:176
# y_predict: [[0.68160987 0.31839016]]
# label_predict:1.0, label_true:1.0
# 今天太阳从西边出来了居然涨了 1.0 1.0
# start:176, end:177
# y_predict: [[0.00403589 0.99596405]]
# label_predict:2.0, label_true:2.0
# 昨天割肉就张，气死 2.0 2.0
# start:177, end:178
# y_predict: [[0.00382486 0.99617517]]
# label_predict:2.0, label_true:2.0
# 指数都涨了你还墨蹟啥 2.0 2.0
# start:178, end:179
# y_predict: [[0.1304003  0.86959964]]
# label_predict:2.0, label_true:2.0
# 你看海能6点，优质股羞不羞 2.0 2.0
# start:179, end:180
# y_predict: [[0.08747658 0.91252345]]
# label_predict:2.0, label_true:2.0
# 頁狗 2.0 2.0
# start:180, end:181
# y_predict: [[0.00189085 0.9981091 ]]
# label_predict:2.0, label_true:2.0
# 整个班级，总他倒数，拖后腿。。。。。 2.0 2.0
# start:181, end:182
# y_predict: [[0.9454314  0.05456859]]
# label_predict:1.0, label_true:1.0
# 企强化上市公司管理提升上市公司市值和价值创造. 资 1.0 1.0
# start:182, end:183
# y_predict: [[0.00338784 0.99661213]]
# label_predict:2.0, label_true:2.0
# 又开始渣了，渣男就是渣男，提起 2.0 2.0
# start:183, end:184
# y_predict: [[0.9026622  0.09733775]]
# label_predict:1.0, label_true:1.0
# 赶紧拉起来！我不允许这样萎靡不振，绩优股就该有个绩 1.0 1.0
# start:184, end:185
# y_predict: [[0.76122665 0.23877332]]
# label_predict:1.0, label_true:1.0
# 午11点前后，大盘涨海控不跟，说明庄家已经控盘，看 1.0 1.0
# start:185, end:186
# y_predict: [[0.03876682 0.9612332 ]]
# label_predict:2.0, label_true:2.0
# 干脆点，来三个跌停板，直接停牌 2.0 2.0
# start:186, end:187
# y_predict: [[1.5244892e-04 9.9984753e-01]]
# label_predict:2.0, label_true:2.0
# 这股真的垃圾。。 2.0 2.0
# start:187, end:188
# y_predict: [[0.1079978  0.89200217]]
# label_predict:2.0, label_true:2.0
# 中远海控，股价跟公司一样，一点脸面不要。 2.0 2.0
# start:188, end:189
# y_predict: [[0.666995   0.33300495]]
# label_predict:1.0, label_true:2.0
# 能上16不？ 2.0 1.0
# start:189, end:190
# y_predict: [[0.6063138  0.39368618]]
# label_predict:1.0, label_true:1.0
# 中远海控～价值重估倒计时！ 1.0 1.0
# start:190, end:191
# y_predict: [[0.00287935 0.9971207 ]]
# label_predict:2.0, label_true:2.0
# #对分红不满，海控中小股东又要 2.0 2.0
# start:191, end:192
# y_predict: [[0.00466061 0.9953394 ]]
# label_predict:2.0, label_true:2.0
# 中远海控暴跌开始了，今天最少跌幅5个点 2.0 2.0
# start:192, end:193
# y_predict: [[0.01894006 0.98105997]]
# label_predict:2.0, label_true:2.0
# 一边停航，一边港口吞吐量同比增 2.0 2.0
# start:193, end:194
# y_predict: [[3.413494e-04 9.996587e-01]]
# label_predict:2.0, label_true:2.0
# 大盘4连阳它4连阴[韭菜] 2.0 2.0
# start:194, end:195
# y_predict: [[0.9804175  0.01958254]]
# label_predict:1.0, label_true:1.0
# 中远海控14元以下，就是最好建仓机会 1.0 1.0
# start:195, end:196
# y_predict: [[0.62127566 0.3787243 ]]
# label_predict:1.0, label_true:2.0
# 要求中远海控中期分红10送50元，太伤小股东的心了 2.0 1.0
# start:196, end:197
# y_predict: [[0.87984145 0.12015859]]
# label_predict:1.0, label_true:2.0
# 买到你就是不涨！ 2.0 1.0
# start:197, end:198
# y_predict: [[0.9648595  0.03514046]]
# label_predict:1.0, label_true:1.0
# 稳定才是硬道理！ 1.0 1.0
# start:198, end:199
# y_predict: [[0.6685561  0.33144388]]
# label_predict:1.0, label_true:1.0
# 一个板马上走 1.0 1.0
# start:199, end:200
# y_predict: [[0.15379274 0.84620726]]
# label_predict:2.0, label_true:1.0
# 压盘收货中，拭目以待 1.0 2.0
# start:200, end:201
# y_predict: [[0.9397169  0.06028321]]
# label_predict:1.0, label_true:1.0
# 今天收获三个点先撤了，下周空仓休息，下下周来炒底。 1.0 1.0
# start:201, end:202
# y_predict: [[0.5370738  0.46292618]]
# label_predict:1.0, label_true:1.0
# 日赚三个亿！今年它比“一哥”还能挣 1.0 1.0
# start:202, end:203
# y_predict: [[0.23703481 0.76296514]]
# label_predict:2.0, label_true:2.0
# 不分红就把股价太高，亲 2.0 2.0
# start:203, end:204
# y_predict: [[0.18162471 0.8183753 ]]
# label_predict:2.0, label_true:2.0
# A50中倒数第三，佩服 2.0 2.0
# start:204, end:205
# y_predict: [[0.00833359 0.9916664 ]]
# label_predict:2.0, label_true:2.0
# 一边忽悠价值投资，一边赚大钱分小钱，赚小钱不分钱， 2.0 2.0
# start:205, end:206
# y_predict: [[0.00381385 0.9961862 ]]
# label_predict:2.0, label_true:2.0
# 唉！人都不想做了！[大哭] 2.0 2.0
# start:206, end:207
# y_predict: [[0.961708   0.03829196]]
# label_predict:1.0, label_true:1.0
# 今天能涨停！！ 1.0 1.0
# start:207, end:208
# y_predict: [[0.00242339 0.99757665]]
# label_predict:2.0, label_true:2.0
# @中远海控，温水煮青蛙，煮了一年了，再不捞起来都糊 2.0 2.0
# start:208, end:209
# y_predict: [[0.7757197  0.22428033]]
# label_predict:1.0, label_true:2.0
# 板块涨你不涨 2.0 1.0
# start:209, end:210
# y_predict: [[0.05207291 0.9479271 ]]
# label_predict:2.0, label_true:2.0
# 天下第一假值股。 2.0 2.0
# start:210, end:211
# y_predict: [[9.0457691e-04 9.9909544e-01]]
# label_predict:2.0, label_true:2.0
# 每天都不死不活的 2.0 2.0
# start:211, end:212
# y_predict: [[2.2998994e-04 9.9976999e-01]]
# label_predict:2.0, label_true:2.0
# 这废物早就吓跑了广大股民 2.0 2.0
# start:212, end:213
# y_predict: [[0.36665484 0.63334525]]
# label_predict:2.0, label_true:2.0
# 轻松买到的都不会涨 2.0 2.0
# start:213, end:214
# y_predict: [[0.22091076 0.7790892 ]]
# label_predict:2.0, label_true:1.0
# 各种迹象表明，要涨了。 1.0 2.0
# start:214, end:215
# y_predict: [[0.9157775  0.08422244]]
# label_predict:1.0, label_true:2.0
# 强弩之末了[空仓] 2.0 1.0
# start:215, end:216
# y_predict: [[0.9095628  0.09043718]]
# label_predict:1.0, label_true:2.0
# 15.38进来又埋 2.0 1.0
# start:216, end:217
# y_predict: [[0.8829176  0.11708238]]
# label_predict:1.0, label_true:1.0
# 起飞 1.0 1.0
# start:217, end:218
# y_predict: [[0.96132374 0.03867624]]
# label_predict:1.0, label_true:1.0
# 加仓10万，中远海控2021年全球航 1.0 1.0
# start:218, end:219
# y_predict: [[0.41441205 0.58558804]]
# label_predict:2.0, label_true:2.0
# 下来吧 2.0 2.0
# start:219, end:220
# y_predict: [[0.06329484 0.9367052 ]]
# label_predict:2.0, label_true:2.0
# 要擦亮眼睛看海控管理层。去年12月29日股东大会授 2.0 2.0
# start:220, end:221
# y_predict: [[0.26915848 0.7308415 ]]
# label_predict:2.0, label_true:1.0
# 【中远海控】真是太优秀了！！！ 1.0 2.0
# start:221, end:222
# y_predict: [[0.00965557 0.99034446]]
# label_predict:2.0, label_true:2.0
# 到底是公司烂？还是投资者烂？为什么国内外、港股的海 2.0 2.0
# start:222, end:223
# y_predict: [[3.2274774e-04 9.9967730e-01]]
# label_predict:2.0, label_true:2.0
# 怎么满屏都是骂钉子的。。。你们就不怕他的粉丝们骂你 2.0 2.0
# start:223, end:224
# y_predict: [[0.8662359  0.13376407]]
# label_predict:1.0, label_true:2.0
# 如果大盘重新回到2800+估计它要 2.0 1.0
# start:224, end:225
# y_predict: [[1.4667639e-04 9.9985325e-01]]
# label_predict:2.0, label_true:2.0
# 大垃圾 2.0 2.0
# start:225, end:226
# y_predict: [[0.87510866 0.12489128]]
# label_predict:1.0, label_true:1.0
# 止跌回稳向上 1.0 1.0
# start:226, end:227
# y_predict: [[0.9231272  0.07687285]]
# label_predict:1.0, label_true:1.0
# 尾市会涨上来的 1.0 1.0
# start:227, end:228
# y_predict: [[0.00250422 0.9974957 ]]
# label_predict:2.0, label_true:2.0
# 天天阴跌 2.0 2.0
# start:228, end:229
# y_predict: [[0.76502043 0.23497957]]
# label_predict:1.0, label_true:2.0
# 四个字，惊弓之鸟 2.0 1.0
# start:229, end:230
# y_predict: [[0.14927304 0.850727  ]]
# label_predict:2.0, label_true:2.0
# 咨讯一出，铺满地雷 2.0 2.0
# start:230, end:231
# y_predict: [[0.98012805 0.01987199]]
# label_predict:1.0, label_true:1.0
# 给优质公司回购点赞！！！ 1.0 1.0
# start:231, end:232
# y_predict: [[0.01232781 0.9876722 ]]
# label_predict:2.0, label_true:2.0
# 啥时候跌停吧 2.0 2.0
# start:232, end:233
# y_predict: [[0.91792256 0.08207739]]
# label_predict:1.0, label_true:1.0
# 预测8月中旬是最大的低，股价会到8-9元附近，留好 1.0 1.0
# start:233, end:234
# y_predict: [[0.99657047 0.00342957]]
# label_predict:1.0, label_true:1.0
# 海控W底已成型了，第一波上升到2O元左右，第二波2 1.0 1.0
# start:234, end:235
# y_predict: [[0.99559635 0.00440372]]
# label_predict:1.0, label_true:1.0
# 3大招加码稳增长，重要信号落地，A股正迎来前所未有 1.0 1.0
# start:235, end:236
# y_predict: [[0.02501447 0.97498554]]
# label_predict:2.0, label_true:2.0
# 周四暴跌，哈哈 2.0 2.0
# start:236, end:237
# y_predict: [[0.06312765 0.93687236]]
# label_predict:2.0, label_true:2.0
# 景气周期都不能被市场认可，以后 2.0 2.0
# start:237, end:238
# y_predict: [[0.9884162  0.01158381]]
# label_predict:1.0, label_true:1.0
# 2.5.26】上升途中的暴跌反而成为买入的时机，昨 1.0 1.0
# start:238, end:239
# y_predict: [[0.8179394 0.1820606]]
# label_predict:1.0, label_true:2.0
# 啊哈又排第一啦 2.0 1.0
# start:239, end:240
# y_predict: [[0.01035408 0.9896459 ]]
# label_predict:2.0, label_true:2.0
# 下午绿五个点 2.0 2.0
# start:240, end:241
# y_predict: [[0.00852807 0.99147195]]
# label_predict:2.0, label_true:2.0
# 倒霉中远股 2.0 2.0
# start:241, end:242
# y_predict: [[0.35900536 0.6409946 ]]
# label_predict:2.0, label_true:2.0
# 明天补跌。 2.0 2.0
# start:242, end:243
# y_predict: [[0.64558923 0.3544108 ]]
# label_predict:1.0, label_true:1.0
# 真是厉害 1.0 1.0
# start:243, end:244
# y_predict: [[0.0030414 0.9969586]]
# label_predict:2.0, label_true:2.0
# 日赚3亿却连年赚3千万都不如 2.0 2.0
# start:244, end:245
# y_predict: [[0.45957884 0.5404212 ]]
# label_predict:2.0, label_true:1.0
# 15.65出了点 1.0 2.0
# start:245, end:246
# y_predict: [[0.8456437  0.15435629]]
# label_predict:1.0, label_true:2.0
# 你就是个得儿 2.0 1.0
# start:246, end:247
# y_predict: [[6.506968e-04 9.993493e-01]]
# label_predict:2.0, label_true:2.0
# 你们吐了吗把我恶心到吐了 2.0 2.0
# start:247, end:248
# y_predict: [[0.15140526 0.84859467]]
# label_predict:2.0, label_true:2.0
# 不怕藏富于企，就怕胡乱作为；不怕巨额现金留存，就怕 2.0 2.0
# start:248, end:249
# y_predict: [[0.20046766 0.7995323 ]]
# label_predict:2.0, label_true:1.0
# 调整了这么久，就不信一次反弹没有，抄底进入 1.0 2.0
# start:249, end:250
# y_predict: [[0.00106917 0.9989309 ]]
# label_predict:2.0, label_true:2.0
# 走的毫无创意，图一30顶背离后30没金叉出买点。图 2.0 2.0
# start:250, end:251
# y_predict: [[0.00191949 0.9980805 ]]
# label_predict:2.0, label_true:2.0
# 最烦织布机！载在张铭文手里了！ 2.0 2.0
# start:251, end:252
# y_predict: [[0.00969409 0.9903059 ]]
# label_predict:2.0, label_true:2.0
# 散户操作——没有启动的无庄股， 2.0 2.0
# start:252, end:253
# y_predict: [[0.01888171 0.98111826]]
# label_predict:2.0, label_true:1.0
# 这个位置跌不到哪去了，因为现在 1.0 2.0
# start:253, end:254
# y_predict: [[0.972674   0.02732599]]
# label_predict:1.0, label_true:1.0
# 丁字裤说明天反弹，大涨 1.0 1.0
# start:254, end:255
# y_predict: [[0.8988791  0.10112091]]
# label_predict:1.0, label_true:1.0
# 如果明年中远继续有今年净利润， 1.0 1.0
# start:255, end:256
# y_predict: [[4.842244e-04 9.995158e-01]]
# label_predict:2.0, label_true:2.0
# 小票跌你跟，小票涨你不跟，学习下茅台 随便同流合污 2.0 2.0
# start:256, end:257
# y_predict: [[0.0426941  0.95730585]]
# label_predict:2.0, label_true:2.0
# 不要脸的公司呀！ 2.0 2.0
# start:257, end:258
# y_predict: [[0.0029675 0.9970325]]
# label_predict:2.0, label_true:2.0
# 同样是中远，为什么海能这么强？？海控这十天都长不过 2.0 2.0
# start:258, end:259
# y_predict: [[0.00175546 0.9982445 ]]
# label_predict:2.0, label_true:2.0
# 这个垃圾有大雷吗，大A涨四天， 2.0 2.0
# start:259, end:260
# y_predict: [[0.00291731 0.99708265]]
# label_predict:2.0, label_true:2.0
# 又画回购大饼授权，主要是为高管股权激励股票拉高减持 2.0 2.0
# start:260, end:261
# y_predict: [[0.5434588  0.45654118]]
# label_predict:1.0, label_true:1.0
# 中远海控一季度净利同比增长78.73% 1.0 1.0
# start:261, end:262
# y_predict: [[0.04234538 0.9576546 ]]
# label_predict:2.0, label_true:1.0
# 牛逼自己给自己压力位 1.0 2.0
# start:262, end:263
# y_predict: [[0.33147308 0.66852695]]
# label_predict:2.0, label_true:1.0
# 坚决打击中远海控做空者...... 1.0 2.0
# start:263, end:264
# y_predict: [[0.21584168 0.7841583 ]]
# label_predict:2.0, label_true:1.0
# 大家一起买，打爆空狗头 1.0 2.0
# start:264, end:265
# y_predict: [[0.0028141 0.9971859]]
# label_predict:2.0, label_true:2.0
# 死垃圾今天总算有点量了 2.0 2.0
# start:265, end:266
# y_predict: [[0.05709472 0.9429053 ]]
# label_predict:2.0, label_true:2.0
# 今天股价的走势很关键，它决定接下来几天走势 2.0 2.0
# start:266, end:267
# y_predict: [[0.970028   0.02997207]]
# label_predict:1.0, label_true:1.0
# 回购是利好，看好未来业绩。 1.0 1.0
# start:267, end:268
# y_predict: [[0.87622356 0.12377641]]
# label_predict:1.0, label_true:1.0
# 周期之花能否花开二茬 1.0 1.0
# start:268, end:269
# y_predict: [[7.2227523e-04 9.9927777e-01]]
# label_predict:2.0, label_true:2.0
# 放心今天还是绿，看都不用看 2.0 2.0
# start:269, end:270
# y_predict: [[0.6674194  0.33258063]]
# label_predict:1.0, label_true:2.0
# 可以涨了，我清仓了 2.0 1.0
# start:270, end:271
# y_predict: [[0.9807505  0.01924954]]
# label_predict:1.0, label_true:1.0
# 明天补涨 1.0 1.0
# start:271, end:272
# y_predict: [[0.9441412  0.05585882]]
# label_predict:1.0, label_true:2.0
# 已经影响很多人股民买车买房和消费了,当诛 2.0 1.0
# start:272, end:273
# y_predict: [[0.07282712 0.9271729 ]]
# label_predict:2.0, label_true:2.0
# 看情形这货又要不行。 2.0 2.0
# start:273, end:274
# y_predict: [[0.00294813 0.99705184]]
# label_predict:2.0, label_true:2.0
# 这货，太无语啦？？？～～～～ 2.0 2.0
# start:274, end:275
# y_predict: [[0.33142135 0.6685786 ]]
# label_predict:2.0, label_true:2.0
# 拿分红说事的基本都是唱空做空的狗，抓到一只打一只就 2.0 2.0
# start:275, end:276
# y_predict: [[0.0040735 0.9959265]]
# label_predict:2.0, label_true:2.0
# 散户的诉求没有得到合理关注，中远海控再失人心！所以 2.0 2.0
# start:276, end:277
# y_predict: [[0.6118229 0.3881771]]
# label_predict:1.0, label_true:1.0
# 买1万股分红8700元，你觉得划算就赶快进 1.0 1.0
# start:277, end:278
# y_predict: [[0.0775288  0.92247117]]
# label_predict:2.0, label_true:2.0
# 尾盘又拉了，和股东大会有关吗？ 2.0 2.0
# start:278, end:279
# y_predict: [[0.9899256  0.01007439]]
# label_predict:1.0, label_true:1.0
# 下周开始上行通道，拿稳了，我薛 1.0 1.0
# start:279, end:280
# y_predict: [[0.20982426 0.7901757 ]]
# label_predict:2.0, label_true:2.0
# 看多咨讯一出，满满地雷感 2.0 2.0
# start:280, end:281
# y_predict: [[0.9654008  0.03459918]]
# label_predict:1.0, label_true:1.0
# 022年分红预测，每十股分15元，专家预言该股脱离 1.0 1.0
# start:281, end:282
# y_predict: [[0.54148865 0.4585113 ]]
# label_predict:1.0, label_true:1.0
# 可以反弹了吧，指数已经反弹100 1.0 1.0
# start:282, end:283
# y_predict: [[5.895473e-04 9.994105e-01]]
# label_predict:2.0, label_true:2.0
# 几分钱搞了一整天。真恶心。 2.0 2.0
# start:283, end:284
# y_predict: [[0.07148229 0.92851776]]
# label_predict:2.0, label_true:2.0
# 今天破14第一天活埋巴菲蛋[大笑] 2.0 2.0
# start:284, end:285
# y_predict: [[4.0970300e-04 9.9959034e-01]]
# label_predict:2.0, label_true:2.0
# 垃圾一个 2.0 2.0
# start:285, end:286
# y_predict: [[0.27213645 0.72786355]]
# label_predict:2.0, label_true:1.0
# 按这个走势不会定向增发吧？按常理不可能啊，不差钱的 1.0 2.0
# start:286, end:287
# y_predict: [[1.2309301e-04 9.9987686e-01]]
# label_predict:2.0, label_true:2.0
# 跌了一年了有完没完还跌 2.0 2.0
# start:287, end:288
# y_predict: [[0.44452518 0.5554748 ]]
# label_predict:2.0, label_true:1.0
# 分红方案很好，多了税多，大部分都是不满一年的 1.0 2.0
# start:288, end:289
# y_predict: [[8.915645e-04 9.991084e-01]]
# label_predict:2.0, label_true:2.0
# 所在板块都是红的就你绿的什么东 2.0 2.0
# start:289, end:290
# y_predict: [[0.88060194 0.11939805]]
# label_predict:1.0, label_true:1.0
# 号外！！！运价，运力期货推出 1.0 1.0
# start:290, end:291
# y_predict: [[0.9099413  0.09005864]]
# label_predict:1.0, label_true:1.0
# 下午拉涨停[大笑] 1.0 1.0
# start:291, end:292
# y_predict: [[0.04061235 0.9593876 ]]
# label_predict:2.0, label_true:2.0
# 暗潮涌动 2.0 2.0
# start:292, end:293
# y_predict: [[0.979938   0.02006207]]
# label_predict:1.0, label_true:1.0
# 缺口已补，接下来就是持股待涨！ 1.0 1.0
# start:293, end:294
# y_predict: [[0.86614907 0.13385092]]
# label_predict:1.0, label_true:2.0
# 今天进的，晚上就能知道踩到什么 2.0 1.0
# start:294, end:295
# y_predict: [[2.2119799e-04 9.9977881e-01]]
# label_predict:2.0, label_true:2.0
# 你真是个垃圾，连中远海发你都跑不过 2.0 2.0
# start:295, end:296
# y_predict: [[0.95886034 0.04113966]]
# label_predict:1.0, label_true:2.0
# 3个涨停回本 2.0 1.0
# start:296, end:297
# y_predict: [[0.00390555 0.9960944 ]]
# label_predict:2.0, label_true:2.0
# 整个股市的跳水冠军，非你莫属 2.0 2.0
# start:297, end:298
# y_predict: [[0.00344545 0.9965546 ]]
# label_predict:2.0, label_true:2.0
# 落魄的龙头不如鸡，现在海能是龙 2.0 2.0
# start:298, end:299
# y_predict: [[0.30499727 0.69500273]]
# label_predict:2.0, label_true:2.0
# 今天跌10个点以上 2.0 2.0
# start:299, end:300
# y_predict: [[3.5613682e-04 9.9964380e-01]]
# label_predict:2.0, label_true:2.0
# 见证了国企的腐朽，其实是普遍现象，割韭菜够狠才能做 2.0 2.0
# start:300, end:301
# y_predict: [[0.09089171 0.90910834]]
# label_predict:2.0, label_true:2.0
# 这就是一个不要的脸的公司 2.0 2.0
# start:301, end:302
# y_predict: [[6.9756927e-05 9.9993026e-01]]
# label_predict:2.0, label_true:2.0
# 要不要这么垃圾 2.0 2.0
# start:302, end:303
# y_predict: [[0.05330956 0.94669044]]
# label_predict:2.0, label_true:2.0
# 明天开始又要跌了 2.0 2.0
# start:303, end:304
# y_predict: [[0.77366006 0.22633995]]
# label_predict:1.0, label_true:1.0
# 比茅台还挣钱的黄金奶牛＝中远海 1.0 1.0
# start:304, end:305
# y_predict: [[0.01085051 0.9891495 ]]
# label_predict:2.0, label_true:2.0
# 别人家猛涨你小涨，别人跌你也跌 2.0 2.0
# start:305, end:306
# y_predict: [[0.35030982 0.6496902 ]]
# label_predict:2.0, label_true:1.0
# 又开始表演了！ 1.0 2.0
# start:306, end:307
# y_predict: [[0.05065473 0.94934523]]
# label_predict:2.0, label_true:2.0
# 天割肉走人，14看样子是历史大顶了，上海航运集装箱 2.0 2.0
# start:307, end:308
# y_predict: [[0.74742055 0.25257948]]
# label_predict:1.0, label_true:1.0
# 难道海王在野蛮筑底中？ 1.0 1.0
# start:308, end:309
# y_predict: [[2.2771064e-04 9.9977225e-01]]
# label_predict:2.0, label_true:2.0
# 什么他m的龙头，真恶心，狗头吧 2.0 2.0
# start:309, end:310
# y_predict: [[0.00446787 0.99553216]]
# label_predict:2.0, label_true:2.0
# 此股就是个流氓！ 2.0 2.0
# start:310, end:311
# y_predict: [[0.40837348 0.59162647]]
# label_predict:2.0, label_true:2.0
# 分红确实挺抠门的 2.0 2.0
# start:311, end:312
# y_predict: [[0.98239106 0.01760892]]
# label_predict:1.0, label_true:1.0
# 外资持有海控量创新高 1.0 1.0
# start:312, end:313
# y_predict: [[0.6430521  0.35694796]]
# label_predict:1.0, label_true:2.0
# 你咋没说25元 2.0 1.0
# start:313, end:314
# y_predict: [[0.07439735 0.9256026 ]]
# label_predict:2.0, label_true:2.0
# 中国人为什么要顺着北向资金去走 2.0 2.0
# start:314, end:315
# y_predict: [[0.02326128 0.9767387 ]]
# label_predict:2.0, label_true:2.0
# 今天的帖子怎么这么少？是删贴了吗？ 2.0 2.0
# start:315, end:316
# y_predict: [[0.03010546 0.9698945 ]]
# label_predict:2.0, label_true:2.0
# 价值投资。呵呵。我笑得撕心裂肺 2.0 2.0
# start:316, end:317
# y_predict: [[0.71928984 0.28071016]]
# label_predict:1.0, label_true:1.0
# 今天又进了5000股[大笑] 1.0 1.0
# start:317, end:318
# y_predict: [[2.8768616e-05 9.9997127e-01]]
# label_predict:2.0, label_true:2.0
# 死垃圾 2.0 2.0
# start:318, end:319
# y_predict: [[0.23456419 0.7654358 ]]
# label_predict:2.0, label_true:2.0
# 为什么中远海能走势这么好 2.0 2.0
# start:319, end:320
# y_predict: [[0.11986829 0.8801318 ]]
# label_predict:2.0, label_true:2.0
# 到14元，也只愿意增持这么点量，说明股价管理层对这 2.0 2.0
# start:320, end:321
# y_predict: [[0.93162847 0.06837156]]
# label_predict:1.0, label_true:1.0
# 今天量足进来先[呲牙][呲牙] 1.0 1.0
# start:321, end:322
# y_predict: [[0.6920494  0.30795062]]
# label_predict:1.0, label_true:2.0
# 开盘看一眼，收盘看一眼，尊重一 2.0 1.0
# start:322, end:323
# y_predict: [[0.0456438  0.95435625]]
# label_predict:2.0, label_true:2.0
# 又出货了 2.0 2.0
# start:323, end:324
# y_predict: [[0.00567868 0.99432135]]
# label_predict:2.0, label_true:2.0
# 一年了，真的快熬不下去了，太浪费行情时间了！ 2.0 2.0
# start:324, end:325
# y_predict: [[0.16120374 0.8387962 ]]
# label_predict:2.0, label_true:2.0
# 呦，砸盘了 2.0 2.0
# start:325, end:326
# y_predict: [[0.81025    0.18975006]]
# label_predict:1.0, label_true:2.0
# 今天起飞不了？ 2.0 1.0
# start:326, end:327
# y_predict: [[0.96106744 0.03893251]]
# label_predict:1.0, label_true:1.0
# 快买快买快买 1.0 1.0
# start:327, end:328
# y_predict: [[0.58643615 0.4135638 ]]
# label_predict:1.0, label_true:2.0
# 高开低走周一 2.0 1.0
# start:328, end:329
# y_predict: [[0.95524377 0.04475626]]
# label_predict:1.0, label_true:1.0
# 港股上涨4.27%！ 1.0 1.0
# start:329, end:330
# y_predict: [[0.2757936 0.7242064]]
# label_predict:2.0, label_true:1.0
# 海能涨停，轮船也快了，海控你还 1.0 2.0
# start:330, end:331
# y_predict: [[0.14864974 0.8513503 ]]
# label_predict:2.0, label_true:1.0
# 为啥就是没人信呢北向目前就是求稳来来回回做T中远海 1.0 2.0
# start:331, end:332
# y_predict: [[0.00172306 0.99827695]]
# label_predict:2.0, label_true:2.0
# 本身分红配股是好事，结果一闹跌 2.0 2.0
# start:332, end:333
# y_predict: [[0.7940749  0.20592512]]
# label_predict:1.0, label_true:1.0
# 今天人气排名要进前十 1.0 1.0
# start:333, end:334
# y_predict: [[0.00814098 0.991859  ]]
# label_predict:2.0, label_true:2.0
# 大盘也赶紧跳水 2.0 2.0
# start:334, end:335
# y_predict: [[0.0361182  0.96388173]]
# label_predict:2.0, label_true:2.0
# 没有一点担当，软骨头 2.0 2.0
# start:335, end:336
# y_predict: [[0.79575366 0.20424637]]
# label_predict:1.0, label_true:1.0
# 我卖了，你才来涨 1.0 1.0
# start:336, end:337
# y_predict: [[0.15764333 0.8423567 ]]
# label_predict:2.0, label_true:2.0
# 明天破13 2.0 2.0
# start:337, end:338
# y_predict: [[0.00356832 0.9964317 ]]
# label_predict:2.0, label_true:1.0
# 烈呼吁别分红了，钱全部用于股权激励，每个高管分10 1.0 2.0
# start:338, end:339
# y_predict: [[0.00108533 0.9989147 ]]
# label_predict:2.0, label_true:2.0
# 我不想宰割肉了[滴汗][滴汗][滴 2.0 2.0
# start:339, end:340
# y_predict: [[0.12859517 0.8714048 ]]
# label_predict:2.0, label_true:2.0
# 价值规律在大A不起作用？ 2.0 2.0
# start:340, end:341
# y_predict: [[1.4945427e-04 9.9985051e-01]]
# label_predict:2.0, label_true:2.0
# 垃圾 2.0 2.0
# start:341, end:342
# y_predict: [[0.01346073 0.9865393 ]]
# label_predict:2.0, label_true:1.0
# 还是那句话，每天买点只买不卖， 1.0 2.0
# start:342, end:343
# y_predict: [[0.00164596 0.9983541 ]]
# label_predict:2.0, label_true:2.0
# 这股票盘子太大，回购也没用，上不去，拉高就跑。 2.0 2.0
# start:343, end:344
# y_predict: [[0.01570365 0.9842964 ]]
# label_predict:2.0, label_true:2.0
# 神阿救救我吧 2.0 2.0
# start:344, end:345
# y_predict: [[0.47769204 0.52230793]]
# label_predict:2.0, label_true:2.0
# 虾虾争斗可休矣！ 2.0 2.0
# start:345, end:346
# y_predict: [[0.22462742 0.7753725 ]]
# label_predict:2.0, label_true:1.0
# 终于回本了！14.45割了海控，出去2.4抄底太平 1.0 2.0
# start:346, end:347
# y_predict: [[7.3110175e-05 9.9992692e-01]]
# label_predict:2.0, label_true:2.0
# 垃圾股，吃垃圾长大的 2.0 2.0
# start:347, end:348
# y_predict: [[0.01662492 0.983375  ]]
# label_predict:2.0, label_true:2.0
# 割肉吧，没戏了，我已清仓 2.0 2.0
# start:348, end:349
# y_predict: [[0.57650024 0.4234997 ]]
# label_predict:1.0, label_true:1.0
# 都开始骂了，很好很好，我入场了 1.0 1.0
# start:349, end:350
# y_predict: [[0.72134715 0.27865285]]
# label_predict:1.0, label_true:1.0
# 明天还有一点小利好 1.0 1.0
# start:350, end:351
# y_predict: [[0.04828468 0.9517153 ]]
# label_predict:2.0, label_true:1.0
# 2倍市盈率，控股股东都经不起诱惑了！ 1.0 2.0
# start:351, end:352
# y_predict: [[0.08569052 0.91430944]]
# label_predict:2.0, label_true:2.0
# 中远海控董事长拒绝参加股东大会 2.0 2.0
# start:352, end:353
# y_predict: [[0.03209094 0.96790904]]
# label_predict:2.0, label_true:2.0
# 竞价万手都不到，废了 2.0 2.0
# start:353, end:354
# y_predict: [[0.03513875 0.9648613 ]]
# label_predict:2.0, label_true:2.0
# 涨得不跟，跌的使劲跟，生 2.0 2.0
# start:354, end:355
# y_predict: [[0.18787919 0.81212085]]
# label_predict:2.0, label_true:2.0
# 新兵报道。正因为是这么低的分红 2.0 2.0
# start:355, end:356
# y_predict: [[0.3305313  0.66946876]]
# label_predict:2.0, label_true:2.0
# 高点一次比一次低 2.0 2.0
# start:356, end:357
# y_predict: [[0.04434743 0.95565253]]
# label_predict:2.0, label_true:1.0
# 怒涨四分 1.0 2.0
# start:357, end:358
# y_predict: [[0.00946325 0.99053675]]
# label_predict:2.0, label_true:2.0
# 铁公鸡，不值得投资关注 2.0 2.0
# start:358, end:359
# y_predict: [[0.04629489 0.95370513]]
# label_predict:2.0, label_true:2.0
# 别头铁坚持这大废物了，我反正是 2.0 2.0
# start:359, end:360
# y_predict: [[0.02088088 0.9791191 ]]
# label_predict:2.0, label_true:2.0
# 什么玩意 2.0 2.0
# start:360, end:361
# y_predict: [[0.01396017 0.9860399 ]]
# label_predict:2.0, label_true:2.0
# 中远绿王 2.0 2.0
# start:361, end:362
# y_predict: [[0.07326403 0.92673594]]
# label_predict:2.0, label_true:2.0
# 港烂继续加仓，也就是说割韭菜高 2.0 2.0
# start:362, end:363
# y_predict: [[0.86594355 0.13405645]]
# label_predict:1.0, label_true:1.0
# 国家鼓励出口，能不利好海运吗 1.0 1.0
# start:363, end:364
# y_predict: [[0.9416979  0.05830209]]
# label_predict:1.0, label_true:1.0
# 明天肯定涨 1.0 1.0
# start:364, end:365
# y_predict: [[1.6944225e-04 9.9983048e-01]]
# label_predict:2.0, label_true:2.0
# 中远垃圾 2.0 2.0
# start:365, end:366
# y_predict: [[0.9478166  0.05218341]]
# label_predict:1.0, label_true:1.0
# 今天超级缩量，有蹊跷[旺柴] 1.0 1.0
# start:366, end:367
# y_predict: [[0.06558117 0.93441886]]
# label_predict:2.0, label_true:2.0
# 最不要脸的公司。 2.0 2.0
# start:367, end:368
# y_predict: [[1.6712061e-04 9.9983287e-01]]
# label_predict:2.0, label_true:2.0
# 这么多人在骂万种，不知道他晚上做不做恶梦 2.0 2.0
# start:368, end:369
# y_predict: [[0.4458456  0.55415434]]
# label_predict:2.0, label_true:2.0
# 还有人在做梦了，好好站岗吧 2.0 2.0
# start:369, end:370
# y_predict: [[0.43888578 0.5611142 ]]
# label_predict:2.0, label_true:1.0
# 太好了！ 1.0 2.0
# start:370, end:371
# y_predict: [[0.00200259 0.99799734]]
# label_predict:2.0, label_true:2.0
# 低开如何操作 2.0 2.0
# start:371, end:372
# y_predict: [[0.02024917 0.9797508 ]]
# label_predict:2.0, label_true:2.0
# 不涨不跌，这货躺平了[大笑][大 2.0 2.0
# start:372, end:373
# y_predict: [[0.19288735 0.80711263]]
# label_predict:2.0, label_true:2.0
# 快跑，收盘一样是15以下 2.0 2.0
# start:373, end:374
# y_predict: [[9.399826e-06 9.999906e-01]]
# label_predict:2.0, label_true:2.0
# 好好的股票被万绿龟搞成了垃圾 2.0 2.0
# start:374, end:375
# y_predict: [[0.61231965 0.38768035]]
# label_predict:1.0, label_true:2.0
# 明天危险了 2.0 1.0
# start:375, end:376
# y_predict: [[0.00655022 0.99344975]]
# label_predict:2.0, label_true:2.0
# 我希望你还能继续做板块倒数第一 2.0 2.0
# start:376, end:377
# y_predict: [[0.00805671 0.99194324]]
# label_predict:2.0, label_true:2.0
# 嘛的，涨的时候不跟，跌的时候， 2.0 2.0
# start:377, end:378
# y_predict: [[0.95733076 0.04266922]]
# label_predict:1.0, label_true:1.0
# 还好早上走了半仓，不出意外，涨 1.0 1.0
# start:378, end:379
# y_predict: [[0.04692597 0.95307404]]
# label_predict:2.0, label_true:2.0
# 不涨了，都不吵吵了吧！ 2.0 2.0
# start:379, end:380
# y_predict: [[0.00841581 0.9915842 ]]
# label_predict:2.0, label_true:2.0
# 国家开始调查船司价格垄断等行为，明天走势如何？ 2.0 2.0
# start:380, end:381
# y_predict: [[1.5935938e-04 9.9984062e-01]]
# label_predict:2.0, label_true:2.0
# 晦气玩意，你一开盘把港股都带绿 2.0 2.0
# start:381, end:382
# y_predict: [[0.99638844 0.00361158]]
# label_predict:1.0, label_true:1.0
# 买入[鼓掌][加油][鼓掌][大笑] 1.0 1.0
# start:382, end:383
# y_predict: [[0.7186743  0.28132567]]
# label_predict:1.0, label_true:2.0
# 你们不但不躺下让庄舒服地割韭菜，竟然胆敢反抗！好， 2.0 1.0
# start:383, end:384
# y_predict: [[0.00582941 0.9941706 ]]
# label_predict:2.0, label_true:2.0
# 中远海绿 2.0 2.0
# start:384, end:385
# y_predict: [[0.00378471 0.9962153 ]]
# label_predict:2.0, label_true:2.0
# 罢免董秘 2.0 2.0
# start:385, end:386
# y_predict: [[0.01294589 0.98705417]]
# label_predict:2.0, label_true:1.0
# 家都不要吵了，想想办法把股价弄60以上去，好吗[微 1.0 2.0
# start:386, end:387
# y_predict: [[0.04737389 0.95262605]]
# label_predict:2.0, label_true:2.0
# 往后14是今年大顶了 2.0 2.0
# start:387, end:388
# y_predict: [[0.07623661 0.92376333]]
# label_predict:2.0, label_true:2.0
# 套的散户太多，主力费了九牛二虎之力才站上十日线。 2.0 2.0
# start:388, end:389
# y_predict: [[0.24865527 0.75134474]]
# label_predict:2.0, label_true:1.0
# 下周海控要大涨！不接受反驳！ 1.0 2.0
# start:389, end:390
# y_predict: [[0.0040398 0.9959602]]
# label_predict:2.0, label_true:2.0
# 17,3的本什么时候能回来呀。还有谁…… 2.0 2.0
# start:390, end:391
# y_predict: [[0.44067898 0.559321  ]]
# label_predict:2.0, label_true:2.0
# 这股赚钱的赶快卖吧不适合长期投资，分红已经明确告诉 2.0 2.0
# start:391, end:392
# y_predict: [[0.8512743  0.14872566]]
# label_predict:1.0, label_true:1.0
# 可以涨了 1.0 1.0
# start:392, end:393
# y_predict: [[0.9897106  0.01028936]]
# label_predict:1.0, label_true:1.0
# 周一一字涨停 1.0 1.0
# start:393, end:394
# y_predict: [[0.03455072 0.9654493 ]]
# label_predict:2.0, label_true:2.0
# 大盘已经出现上涨乏力的状态，已经徘徊通道线的底部， 2.0 2.0
# start:394, end:395
# y_predict: [[0.18549302 0.81450707]]
# label_predict:2.0, label_true:1.0
# 主力在拼命拉高，你们发那么多反 1.0 2.0
# start:395, end:396
# y_predict: [[0.86952394 0.13047601]]
# label_predict:1.0, label_true:1.0
# 必上16 1.0 1.0
# start:396, end:397
# y_predict: [[0.99247783 0.00752224]]
# label_predict:1.0, label_true:1.0
# 能有业绩支撑，强势中，继续持股，个人观点。[握手] 1.0 1.0
# start:397, end:398
# y_predict: [[0.00438352 0.99561644]]
# label_predict:2.0, label_true:2.0
# 的海绿 2.0 2.0
# start:398, end:399
# y_predict: [[0.41177106 0.58822894]]
# label_predict:2.0, label_true:2.0
# 至少拿300亿来分 2.0 2.0
# start:399, end:400
# y_predict: [[0.80473727 0.19526273]]
# label_predict:1.0, label_true:2.0
# 这个老六，我是服了 2.0 1.0
# start:400, end:401
# y_predict: [[0.0126974  0.98730266]]
# label_predict:2.0, label_true:2.0
# 衰股 2.0 2.0
# start:401, end:402
# y_predict: [[0.03915678 0.9608432 ]]
# label_predict:2.0, label_true:2.0
# 个个都减持，怎么涨啊 2.0 2.0
# start:402, end:403
# y_predict: [[0.04725783 0.95274216]]
# label_predict:2.0, label_true:2.0
# 真的是中海龟了 2.0 2.0
# start:403, end:404
# y_predict: [[0.00606942 0.9939306 ]]
# label_predict:2.0, label_true:2.0
# 恶心 2.0 2.0
# start:404, end:405
# y_predict: [[0.88752943 0.11247054]]
# label_predict:1.0, label_true:1.0
# 涨不停 1.0 1.0
# start:405, end:406
# y_predict: [[0.80079144 0.19920856]]
# label_predict:1.0, label_true:2.0
# 实在坚持不住了。。。兄弟们你们 2.0 1.0
# start:406, end:407
# y_predict: [[0.97172517 0.02827481]]
# label_predict:1.0, label_true:1.0
# 波罗的海海运指数昨晚又创新高了。今天轮到A股海运龙 1.0 1.0
# start:407, end:408
# y_predict: [[0.02021855 0.9797815 ]]
# label_predict:2.0, label_true:2.0
# 早盘诱多，主力卖盘出货，估计收 2.0 2.0
# start:408, end:409
# y_predict: [[0.60394245 0.39605755]]
# label_predict:1.0, label_true:1.0
# 远海控上60元一股也不过分，不如他的宁德时代股价凭 1.0 1.0
# start:409, end:410
# y_predict: [[0.00755455 0.9924454 ]]
# label_predict:2.0, label_true:2.0
# 中远海控资本运作才刚刚开始…刚收购中远海运集团财务 2.0 2.0
# start:410, end:411
# y_predict: [[0.15916829 0.8408317 ]]
# label_predict:2.0, label_true:2.0
# 快跑呀慢的要受伤 2.0 2.0
# start:411, end:412
# y_predict: [[0.93486476 0.06513527]]
# label_predict:1.0, label_true:1.0
# 主力拉升，没有悬念 1.0 1.0
# start:412, end:413
# y_predict: [[0.714305 0.285695]]
# label_predict:1.0, label_true:1.0
# 下寻支撑 1.0 1.0
# start:413, end:414
# y_predict: [[0.4263273 0.5736728]]
# label_predict:2.0, label_true:2.0
# 二跳空低开，先到13.7，大概率失守，继续13.2 2.0 2.0
# start:414, end:415
# y_predict: [[1.4584184e-04 9.9985409e-01]]
# label_predict:2.0, label_true:2.0
# 整个海远港口版本中远海控最垃圾 2.0 2.0
# start:415, end:416
# y_predict: [[0.21648888 0.78351116]]
# label_predict:2.0, label_true:2.0
# 下跌趋势改变不了的，好好站岗吧 2.0 2.0
#
#  finsh training model:  data\qgfx\qgfx.h5

# %% [markdown]
# ## LSTM 预测情感(时间很长)

# %%
qgfxmodel.predict_qg('中远海控','data\\qgfx\\qgfx.h5','data\\qgfx\\train_Data.csv','data\\qgfx\\中远海控股吧.csv',25)

# %% [markdown]
# ## LSTM 多维度时序预测

# %%
dwsxfx.process_data('中远海控','data\\qgfx\\qg_predicted.csv','data\\sxfx\\time_train_Data.csv')
pred,zs = dwsxfx.train_model('data\\sxfx\\time_train_Data.csv',[5],[5],1)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
# Epoch 1/5
# 6/6 [==============================] - 7s 203ms/step - loss: 0.2058 - val_loss: 0.2279
# Epoch 2/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1793 - val_loss: 0.1994
# Epoch 3/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1536 - val_loss: 0.1688
# Epoch 4/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1248 - val_loss: 0.1364
# Epoch 5/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1037 - val_loss: 0.1029
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0859
# Epoch 1/5
# 6/6 [==============================] - 7s 172ms/step - loss: 0.2104 - val_loss: 0.2218
# Epoch 2/5
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1799 - val_loss: 0.1903
# Epoch 3/5
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1520 - val_loss: 0.1569
# Epoch 4/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1180 - val_loss: 0.1220
# Epoch 5/5
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0877 - val_loss: 0.0876
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0726
# Epoch 1/5
# 6/6 [==============================] - 9s 188ms/step - loss: 0.2220 - val_loss: 0.2666
# Epoch 2/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2223 - val_loss: 0.2665
# Epoch 3/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2216 - val_loss: 0.2665
# Epoch 4/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2224 - val_loss: 0.2664
# Epoch 5/5
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2219 - val_loss: 0.2664
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2371
# Epoch 1/5
# 6/6 [==============================] - 9s 266ms/step - loss: 0.2272 - val_loss: 0.2584
# Epoch 2/5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2273 - val_loss: 0.2584
# Epoch 3/5
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2276 - val_loss: 0.2584
# Epoch 4/5
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2271 - val_loss: 0.2583
# Epoch 5/5
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2274 - val_loss: 0.2583
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2140
# Epoch 1/5
# 12/12 [==============================] - 7s 144ms/step - loss: 0.1980 - val_loss: 0.1991
# Epoch 2/5
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1416 - val_loss: 0.1329
# Epoch 3/5
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0851 - val_loss: 0.0681
# Epoch 4/5
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0458 - val_loss: 0.0298
# Epoch 5/5
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0391 - val_loss: 0.0226
# {'batch_size': 5, 'epochs': 5, 'optimizer': 'adam'}
# 保存在 out\time_pred.jpg

# %% [markdown]
# ## pyecharts 绘制单只股票投资透支图

# %%
screen_touzi.touzi_toushi('中远海控',pred,zs,'data\\qgfx\\中远海控股吧.csv')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
# Loading model cost 0.963 seconds.
# Prefix dict has been built successfully.
# 请前往out\投资透视图待调整.html调整网页布局

# %% [markdown]
# ## pyecharts 布局函数

# %%
pyedraw.buju('out\\危机相关经济数据1.0.html','out\\j1.json','out\\危机相关经济数据.html')
screen_touzi.buju('out\\投资透视图待调整.html','out\\j2.json','out\\中远海控投资透视.html')
